# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import keras as K
import matplotlib.pyplot as plt
from keract import *
from PIL import Image

# %matplotlib inline

# %%
def tensor_to_image(tensor):
    tensor = tensor*255
    tensor = np.array(tensor, dtype=np.uint8)
    if np.ndim(tensor)>3:
        assert tensor.shape[0] == 1
    tensor = tensor[0]
    return Image.fromarray(tensor)

# %%
def load_img(path_to_img):
    max_dim = 512
    img = tf.io.read_file(path_to_img)
    img = tf.image.decode_image(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)

    shape = tf.cast(tf.shape(img)[:-1], tf.float32)
    long_dim = max(shape)
    scale = max_dim / long_dim

    new_shape = tf.cast(shape * scale, tf.int32)

    img = tf.image.resize(img, new_shape)
    img = img[tf.newaxis, :]
    return img

# %%
def imshow(image, title=None):
    if len(image.shape) > 3:
        image = tf.squeeze(image, axis=0)

    plt.imshow(image)
    if title:
        plt.title(title)

# %%
s_image = Image.open('jojo.png')
s_image = s_image.crop((0, 0, 224, 224))
s_image = tf.keras.preprocessing.image.img_to_array(s_image)
s_image = s_image.reshape((1, s_image.shape[0], s_image.shape[1], s_image.shape[2]))

# %%
imshow(c_image)

# %%
imshow(s_image)
s_update=tf.reshape(s_image,[1,224,224,3])
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-24-69ab6ab90d3d> in <module>
#       1 imshow(s_image)
# ----> 2 s_update=tf.reshape(s_image,[1,224,224,3])
#
# ~\AppData\Roaming\Python\Python36\site-packages\tensorflow_core\python\ops\array_ops.py in reshape(tensor, shape, name)
#     129     A `Tensor`. Has the same type as `tensor`.
#     130   """
# --> 131   result = gen_array_ops.reshape(tensor, shape, name)
#     132   tensor_util.maybe_set_static_shape(result, shape)
#     133   return result
#
# ~\AppData\Roaming\Python\Python36\site-packages\tensorflow_core\python\ops\gen_array_ops.py in reshape(tensor, shape, name)
#    8104       try:
#    8105         return reshape_eager_fallback(
# -> 8106             tensor, shape, name=name, ctx=_ctx)
#    8107       except _core._SymbolicException:
#    8108         pass  # Add nodes to the TensorFlow graph.
#
# ...

# %%
vgg = tf.keras.applications.VGG19(include_top='False', weights='imagenet')
vgg.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...

# %%
vgg.compile(optimizer='adam', loss='categorical_crossentropy')

# %%
preproc_image = tf.keras.applications.vgg19.preprocess_input(s_image*225.0)
preproc_image
# Out:
# <tf.Tensor: id=1863, shape=(1, 288, 512, 3), dtype=float32, numpy=
# array([[[[ 32.27424 , -31.190758, -94.01088 ],
#          [ 32.27424 , -31.190758, -94.01088 ],
#          [ 32.27424 , -31.190758, -94.01088 ],
#          ...,
#          [ 29.006783, -28.543694, -96.65794 ],
#          [ 27.641884, -27.17881 , -95.84452 ],
#          [ 30.85421 , -23.56668 , -91.80499 ]],
#
#         [[ 36.465416, -30.308403, -98.20206 ],
#          [ 36.465416, -30.308403, -98.20206 ],
#          [ 36.465416, -30.308403, -98.20206 ],
#          ...,
#          [ 34.590416, -28.543694, -99.759964],
#          [ 35.47277 , -28.543694, -98.97411 ],
#          [ 35.47277 , -27.661346, -98.97411 ]],
#
#         [[ 38.11982 , -30.308403, -98.97411 ],
#          [ 38.11982 , -30.308403, -98.97411 ],
#          [ 38.11982 , -30.308403, -98.97411 ],
#          ...,
#          [ 36.244835, -28.543694, -99.85647 ],
#          [ 35.47277 , -28.543694, -99.08441 ],
# ...

# %%
acts = get_activations(vgg,tf.keras.applications.vgg19.preprocess_input(s_image*225.0))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Desktop\DataScienceProjects\JoJoStyle\keract.py in _evaluate(model, nodes_to_evaluate, x, y, auto_compile)
#      47     try:
# ---> 48         return eval_fn(model._feed_inputs + model._feed_targets + model._feed_sample_weights)
#      49     except Exception:
#
# ~\Desktop\DataScienceProjects\JoJoStyle\keract.py in eval_fn(k_inputs)
#      42         try:
# ---> 43             return K.function(k_inputs, nodes_to_evaluate)(model._standardize_user_data(x, y))
#      44         except AttributeError:  # one way to avoid forcing non eager mode.
#
# ~\AppData\Roaming\Python\Python36\site-packages\tensorflow_core\python\keras\engine\training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, batch_size, check_steps, steps_name, steps, validation_split, shuffle, extract_tensors_from_dataset)
# ...
